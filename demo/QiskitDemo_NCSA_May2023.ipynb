# %% [markdown]
# This demonstration was presented to the NCSA QC interest group on 5/22/2023 by Bruno Abreu.
#
# If you have questions, please write to babreu@illinois.edu
#
# The content is strongly based on IBM Quantum's Qiskit Intro courses:
# - https://learn.qiskit.org/course/introduction/why-quantum-computing
# - https://learn.qiskit.org/course/machine-learning/introduction

# %% [markdown]
# # Environment setup

# %% [markdown]
# `qiskit` is straightforward to install using `pip`. For more information, please visit their documentation: https://qiskit.org/documentation/getting_started.html

# %%
# !pip install qiskit[visualization] qiskit-machine-learning
# Out:
# Requirement already satisfied: qiskit[visualization] in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (0.43.0)
# Collecting qiskit-machine-learning
#   Downloading qiskit_machine_learning-0.6.1-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.7/148.7 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: qiskit-terra==0.24.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (0.24.0)
# Requirement already satisfied: qiskit-aer==0.12.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (0.12.0)
# Requirement already satisfied: qiskit-ibmq-provider==0.20.2 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (0.20.2)
# Requirement already satisfied: matplotlib>=2.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (3.7.1)
# Requirement already satisfied: ipywidgets>=7.3.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (8.0.6)
# Requirement already satisfied: pydot in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (1.4.2)
# Requirement already satisfied: pillow>=4.2.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (9.5.0)
# Requirement already satisfied: pylatexenc>=1.4 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (0.12.2)
# Requirement already satisfied: pygments>=2.4 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit[visualization]) (2.15.1)
# Requirement already satisfied: numpy>=1.16.3 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-aer==0.12.0->qiskit[visualization]) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-aer==0.12.0->qiskit[visualization]) (1.10.1)
# Requirement already satisfied: requests>=2.19 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (2.30.0)
# Requirement already satisfied: requests-ntlm<=1.1.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (1.1.0)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (1.5.1)
# Requirement already satisfied: websockets>=10.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (11.0.3)
# Requirement already satisfied: rustworkx>=0.12.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-terra==0.24.0->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: ply>=3.10 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-terra==0.24.0->qiskit[visualization]) (3.11)
# Requirement already satisfied: psutil>=5 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-terra==0.24.0->qiskit[visualization]) (5.9.5)
# Requirement already satisfied: sympy>=1.3 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-terra==0.24.0->qiskit[visualization]) (1.12)
# Requirement already satisfied: dill>=0.3 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-terra==0.24.0->qiskit[visualization]) (0.3.6)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-terra==0.24.0->qiskit[visualization]) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-terra==0.24.0->qiskit[visualization]) (0.9.2)
# Collecting scikit-learn>=0.20.0
#   Downloading scikit_learn-1.2.2-cp311-cp311-macosx_10_9_x86_64.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 26.2 MB/s eta 0:00:0000:0100:01
# Collecting fastdtw
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=40.1.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from qiskit-machine-learning) (66.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (6.23.1)
# Requirement already satisfied: ipython>=6.1.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (8.13.2)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipywidgets>=7.3.0->qiskit[visualization]) (3.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from matplotlib>=2.1->qiskit[visualization]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from matplotlib>=2.1->qiskit[visualization]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from matplotlib>=2.1->qiskit[visualization]) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from matplotlib>=2.1->qiskit[visualization]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from matplotlib>=2.1->qiskit[visualization]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from matplotlib>=2.1->qiskit[visualization]) (3.0.9)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 23.8 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pandas>=0.25 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.0.1)
# Requirement already satisfied: appnope in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (1.5.6)
# Requirement already satisfied: pyzmq>=20 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (6.3.2)
# Requirement already satisfied: backcall in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.2.0)
# Requirement already satisfied: decorator in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (3.0.38)
# Requirement already satisfied: stack-data in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (4.8.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from pandas>=0.25->seaborn>=0.9.0->qiskit[visualization]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from pandas>=0.25->seaborn>=0.9.0->qiskit[visualization]) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (2023.5.7)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (40.0.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from stevedore>=3.0.0->qiskit-terra==0.24.0->qiskit[visualization]) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from sympy>=1.3->qiskit-terra==0.24.0->qiskit[visualization]) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (1.15.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit[visualization]) (3.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.3.0->qiskit[visualization]) (0.2.2)
# Requirement already satisfied: pycparser in /Users/babreu/opt/anaconda3/envs/qiskit/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit[visualization]) (2.21)
# Building wheels for collected packages: fastdtw
#   Building wheel for fastdtw (setup.py) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-py3-none-any.whl size=3564 sha256=f66a301c35707412569b1f5ba96765b640b27dfc7d99c2d88a9e35ee3d0677f5
#   Stored in directory: /Users/babreu/Library/Caches/pip/wheels/5c/8a/f6/fd3df9a9714677410a5ccbf3ca519e66db4a54a1c46ea95332
# Successfully built fastdtw
# Installing collected packages: threadpoolctl, joblib, fastdtw, scikit-learn, qiskit-machine-learning
# Successfully installed fastdtw-0.3.4 joblib-1.2.0 qiskit-machine-learning-0.6.1 scikit-learn-1.2.2 threadpoolctl-3.1.0

# %% [markdown]
# # Building quantum circuits

# %% [markdown]
# `qiskit` is a platform for quantum programming using the circuit-based model. The programmer defines *qubits*, the quantum counterparts of bits, and perform gate operations on them to achieve a desired outcome. We will use the `QuantumCircuit` class: https://qiskit.org/documentation/stubs/qiskit.circuit.QuantumCircuit.html

# %% [markdown]
# ## Defining and visualizing a quantum circuit

# %% [markdown]
# By default, qubits are initialized in the $\lvert 0 \rangle$ state.

# %%
from qiskit import QuantumCircuit

# %%
qc = QuantumCircuit(3,3) # defines a quantum circuit with 3 quantum registers and 3 classical registers (to store measurements)

# %%
qc.draw('mpl')

# %% [markdown]
# ## Applying gates

# %% [markdown]
# Gates are operations that can be applied on single or multiple qubits. Typically, these operations create superposition and entanglement between quantum states and qubits, and are expressed through unitary transformations. A list of possible gates is available here: https://qiskit.org/documentation/tutorials/circuits/3_summary_of_quantum_operations.html#
#
#
# Below, we apply a few gates to the the circuit 3-qubit `qc` defined on the previous section.

# %%
qc.h(0) # apply a Hadamard gate on qubit 0
qc.cx(2,1) # apply a CNOT gate with control and target qubits 2 and 1, respectively
qc.ry(0.785, 0) # apply a 45 degrees rotation around the Y-axis for qubit 0
qc.ccx(0,1,2) # apply a Toffoli gate on all three-qubits, with the last one being the target
qc.x(0) # apply a Pauli X gate on qubit 0
qc.y(1) # apply a Pauli Y gate on qubit 1
qc.z(2) # apply a Pauli Z gate in qubit 2

# %%
qc.draw('mpl')

# %% [markdown]
# ## Measuring circuit outcomes

# %% [markdown]
# After superposition and entaglement are created, we are typically interested in measuring the state of one or multiple qubits, and assigning the outcome to the corresponding *classical* bit. With `qiskit`, measurements are always on the $Z$-basis ($\lvert 0 \rangle$ and $\lvert 1 \rangle$, the eigenstates of the Pauli Z matrix).

# %%
qc.measure([0,1,2], [0,1,2]) # measure qubits 0, 1, and 2, and assign outcome to classical bits 0, 1, and 2

# %%
qc.draw('mpl')

# %% [markdown]
# ## Visualizing qubits states

# %% [markdown]
# When using unitary transformations, it is possible to keep track of the quantum state of each qubit by simply performing the product of each gate and applying it to the initial state of the qubit. This can be done with the `Statevector` class: https://qiskit.org/documentation/stubs/qiskit.quantum_info.Statevector.html

# %%
from qiskit.quantum_info import Statevector

# %%
qc_simple = QuantumCircuit(2)
qc_simple.h(0) # create a superposition on qubit 0
qc_simple.ry(0.785, 1) # rotate qubit 1 around the y-axis
qc_simple.draw('mpl')

# %%
ket_simple = Statevector(qc_simple) # calculate the vector state associated to this circuit

# %%
ket_simple.draw('bloch') # plot the states on Bloch spheres

# %%
qc_ent = QuantumCircuit(2) # circuit with two qubits
qc_ent.h(0) # superposition in the first qubit
qc_ent.cx(0,1) # CNOT with the first and second, creating a Bell state
qc_ent.draw('mpl')

# %%
ket = Statevector(qc_ent)

# %%
ket.draw('latex') # print the latex quantum state
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
ket.draw('qsphere') # draw the Qsphere representation: https://qiskit.org/documentation/stubs/qiskit.visualization.plot_state_qsphere.html

# %% [markdown]
# # Pre-built circuits

# %% [markdown]
# Of course, in designing quantum applications from bottom up using the circuit-based model, patterns emerge, and certain circuit slices are always appearing. Some of these are implemented in `qiskit.circuit.library`: https://qiskit.org/documentation/apidoc/circuit_library.html
#
# For instance, in the context of Quantum Machine Learning, the second-order Pauli-Z evolution circuit (`ZZFeatureMap`) is often used to encode classical data into quantum states: https://qiskit.org/documentation/stubs/qiskit.circuit.library.ZZFeatureMap.html#qiskit.circuit.library.ZZFeatureMap
#
# This is also an example of a *parametrized* circuit.

# %%
from qiskit.circuit.library import ZZFeatureMap

# %%
qc_zz = ZZFeatureMap(3, reps=1)  # circuit to encode a dataset with 3 features

# %%
qc_zz.draw('mpl')

# %%
qc_zz.decompose().draw('mpl')

# %% [markdown]
# # Simulating circuits

# %% [markdown]
# After a circuit is built, the programmer wants to measure the outcome several times to understand the probability distribution associated to them. `qiskit` implements a simulator in its `Aer` module: https://qiskit.org/documentation/tutorials/simulators/1_aer_provider.html
#
# `Aer` allows the programmer to choose between several simulation methods, such as density matrix, matrix product states, and others, to account for things such as noisy gate operations (non-unitary transformations).

# %%
from qiskit import Aer
from qiskit.visualization import plot_histogram

# %%
sim = Aer.get_backend('aer_simulator')  # set up the backend as the Aer simulator (it could be a real quantum computer as well!)

# %%
qc = QuantumCircuit(3, 3)  # 3 qubits with 3 classical bits
qc.ry(1.911, 1)
qc.cx(1, 0)
qc.ry(0.785, 0)
qc.cx(1, 0)
qc.ry(2.356, 0)
qc.ccx(0, 1, 2)
qc.measure([0,1,2], [0,1,2])
qc.draw('mpl')

# %%
job = sim.run(qc) # dispatch the circuit to the quantum simulator

# %%
job.result() #  visualize metadata
# Out:
# Result(backend_name='aer_simulator', backend_version='0.12.0', qobj_id='', job_id='c7fdaf6b-287d-4573-bf78-b38f32b54062', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x1': 324, '0x2': 344, '0x7': 356}), header=QobjExperimentHeader(creg_sizes=[['c', 3]], global_phase=0.0, memory_slots=3, metadata=None, n_qubits=3, name='circuit-144', qreg_sizes=[['q', 3]]), status=DONE, seed_simulator=1045776988, metadata={'parallel_state_update': 10, 'parallel_shots': 1, 'sample_measure_time': 0.000386917, 'noise': 'ideal', 'batched_shots_optimization': False, 'remapped_qubits': False, 'device': 'CPU', 'active_input_qubits': [0, 1, 2], 'measure_sampling': True, 'num_clbits': 3, 'input_qubit_map': [[0, 0], [1, 1], [2, 2]], 'num_qubits': 3, 'method': 'statevector', 'fusion': {'applied': False, 'max_fused_qubits': 5, 'threshold': 14, 'enabled': True}}, time_taken=0.0015825)], date=2023-05-19T11:43:33.590239, status=COMPLETED, header=None, metadata={'mpi_rank': 0, 'num_mpi_processes': 1, 'num_processes_per_experiments': 1, 'max_gpu_memory_mb': 0, 'time_taken_execute': 0.001625083, 'max_memory_mb': 65536, 'parallel_experiments': 1, 'omp_enabled': True}, time_taken=0.0021469593048095703)

# %% [markdown]
# ## Analyzing and visualizing simulation results

# %% [markdown]
# After running the simulations, we can get the exact counts or plot them in a histogram. The `result()` method returns an object that offers several of these features: https://qiskit.org/documentation/stubs/qiskit.result.Result.html

# %%
result = job.result()

# %%
result.get_counts()
# Out:
# {'001': 324, '010': 344, '111': 356}

# %%
plot_histogram(result.get_counts())

# %% [markdown]
# ## Controling simulation shots

# %% [markdown]
# It is possible to adjust several options and features for the selected backend simulator. Of particular interest is the total number of shots (how many times the circuit is prepared and measured), as well as whether or not to record each outcome:

# %%
job_mem = sim.run(qc, shots=25, memory=True)

# %%
result_mem = job_mem.result()

# %%
mem = result_mem.get_memory(qc)

# %%
print(mem)
# Out:
# ['001', '111', '001', '001', '001', '001', '111', '001', '001', '001', '010', '111', '001', '111', '111', '010', '001', '010', '001', '111', '111', '001', '111', '010', '010']

# %% [markdown]
# The default number of shots for the Aer simulator is 1024, which is often not enough for non-trivial circuits.

# %%
job_big = sim.run(qc, shots=1024*1024)
result_big = job_big.result()
plot_histogram(result_big.get_counts())

# %% [markdown]
# # Application examples

# %% [markdown]
# ## Quantum communication

# %% [markdown]
# One important application of quantum computing is that, given very special conditions that establish intrinsic quantum correlations, it is possible to transmit information via qubits more concisely than it would be via classical bits. This is commonly referred to as *superdense coding*. Suppose we want to communicate a two-bits message ($00$, $01$, $01$, or $11$) from Alice to Bob.

# %%
sim = Aer.get_backend('aer_simulator')

# %% [markdown]
# ### Manipulating two qubits
#
# As we know now, `qiskit` initializes qubits in the $\lvert 0 \rangle$ state. Making use of the Pauli-X gate, we can flip the qubit state between $\lvert 0 \rangle$ and $\lvert 1 \rangle$ to encode the message using two-qubits, pass these two-qubits to Bob, who can then make a measurement and decode the message.

# %% [markdown]
# #### Transmit 00

# %%
# transmit "00" message
qc_alice = QuantumCircuit(2) # qubits 0 and 1 are already in the 0 state

qc_bob = QuantumCircuit(2,2)
qc_bob.measure([0,1], [0,1])

# %%
qc_alice.draw('mpl')

# %%
qc_bob.draw('mpl')

# %%
complete_qc = qc_alice.compose(qc_bob)
job = sim.run(complete_qc)
job.result().get_counts()
# Out:
# {'00': 1024}

# %% [markdown]
# #### Transmit 01

# %%
# transmit "01" message
qc_alice = QuantumCircuit(2) # qubits 0 and 1 are already in the 0 state
qc_alice.x(0) # flip state of qubit 0

qc_bob = QuantumCircuit(2,2)
qc_bob.measure([0,1], [0,1])

# %%
complete_qc = qc_alice.compose(qc_bob)

# %%
complete_qc.draw('mpl')

# %%
job = sim.run(complete_qc)
job.result().get_counts()
# Out:
# {'01': 1024}

# %% [markdown]
# #### Transmit 10

# %%
# transmit "01" message
qc_alice = QuantumCircuit(2) # qubits 0 and 1 are already in the 0 state
qc_alice.x(1) # flip state of qubit 1

qc_bob = QuantumCircuit(2,2)
qc_bob.measure([0,1], [0,1])

# %%
complete_qc = qc_alice.compose(qc_bob)
complete_qc.draw('mpl')

# %%
job = sim.run(complete_qc)
job.result().get_counts()
# Out:
# {'10': 1024}

# %% [markdown]
# #### Transmmit 11

# %%
# transmit "01" message
qc_alice = QuantumCircuit(2) # qubits 0 and 1 are already in the 0 state
qc_alice.x(0) # flip stateo f qubit 0
qc_alice.x(1) # flip state of qubit 1

qc_bob = QuantumCircuit(2,2)
qc_bob.measure([0,1], [0,1])

# %%
complete_qc = qc_alice.compose(qc_bob)
complete_qc.draw('mpl')

# %%
job = sim.run(complete_qc)
job.result().get_counts()
# Out:
# {'11': 1024}

# %% [markdown]
# ### Manipulating a single qubit
#
# Although the communication is working, it is possible to make it more dense. We can use entanglement in a way that allows for Alice to encode a two-bit message by manipulating and sending to Bob a single qubit. To create the entanglement, we use a third character, Charlie.

# %%
qc_charlie = QuantumCircuit(2)
qc_charlie.h(1)  # superpose
qc_charlie.cx(1,0) # create Bell pair
qc_charlie.draw('mpl')

# %% [markdown]
# Charlie then sends one of these entangled qubit to Alice, and one to Bob. Alice performs some operation on that qubit to encode the two-bit message, and when Bob receives it, Bob disentangles the qubits to decode the message. Since we are dealing with unitary gates, operations are reversible, so Bob needs to, before measuring the states of the two qubits, perform the same operations that Charlie used to prepare the entanglement, in reverse order:

# %%
qc_bob = QuantumCircuit(2,2)
qc_bob.cx(1,0)  # cnot
qc_bob.h(1)  # hadamard
qc_bob.measure([0,1], [0,1])
qc_bob.draw('mpl')

# %% [markdown]
# #### Transmit 00

# %%
qc_alice = QuantumCircuit(2)

complete_qc = qc_charlie.compose(qc_alice.compose(qc_bob))
complete_qc.draw('mpl')

# %%
job = sim.run(complete_qc)
job.result().get_counts()
# Out:
# {'00': 1024}

# %% [markdown]
# #### Transmit 01
#
# The qubits that Charlie prepares are in the Bell state:
#
# $\lvert \psi \rangle = \frac{1}{\sqrt{2}}\left(\lvert 00 \rangle + \lvert 11 \rangle  \right)$.
#
# Given these delicate quantum correlations, Alice can then encode a two-bit message by performing operations in just one of them.

# %%
qc_alice = QuantumCircuit(2)
qc_alice.x(1)

complete_qc = qc_charlie.compose(qc_alice.compose(qc_bob))
complete_qc.draw('mpl')

# %%
job = sim.run(complete_qc)
job.result().get_counts()
# Out:
# {'01': 1024}

# %% [markdown]
# #### Transmit 10

# %%
qc_alice = QuantumCircuit(2)
qc_alice.z(1)

complete_qc = qc_charlie.compose(qc_alice.compose(qc_bob))
complete_qc.draw('mpl')

# %%
job = sim.run(complete_qc)
job.result().get_counts()
# Out:
# {'10': 1024}

# %% [markdown]
# #### Transmit 11

# %%
qc_alice = QuantumCircuit(2)
qc_alice.x(1)
qc_alice.z(1)

complete_qc = qc_charlie.compose(qc_alice.compose(qc_bob))
complete_qc.draw('mpl')

# %%
job = sim.run(complete_qc)
job.result().get_counts()
# Out:
# {'11': 1024}

# %% [markdown]
# ## Quantum machine learning

# %% [markdown]
# ### Parametrized circuits
#
# So far we have worked with quantum circuits composed of qubits and specific gates that perform operations over qubits. The first layer of abstraction to this model encompasses the use of parametric gates, where the unitary transformation corresponding to the gate is parametrized via one or more parameters. More information about these circuits can be found here: https://qiskit.org/documentation/tutorials/circuits_advanced/01_advanced_circuits.html#Parameterized-circuits
#
# Below is a simple example of such a circuit:

# %%
from qiskit.circuit import ParameterVector

# %%
theta_list = ParameterVector('t', length=2)
qc = QuantumCircuit(2,2)
qc.ry(theta_list[0], 1)   # parametrize a Y-rotation gate with the first parameter
qc.rx(theta_list[1], 0) # parametrize a X-rotation gate with the second parameter
qc.cx(0,1)
qc.measure([0,1], [0,1])
qc.draw('mpl')

# %% [markdown]
# We can then study the parametrized circuit's output as we traverse the parameter map using simulations:

# %%
import numpy as np

# %%
x = np.linspace(0, np.pi/2, 5)

# %%
sim = Aer.get_backend('aer_simulator')

# %%
# assign a set of parameters to the circuit
qc_assigned = qc.assign_parameters([x[2], x[3]])
qc_assigned.draw('mpl')

# %%
for t0 in x:
    for t1 in x:
        qc_assigned = qc.assign_parameters([t0,t1])
        job = sim.run(qc_assigned)
        print(t0, t1, job.result().get_counts())
# Out:
# 0.0 0.0 {'00': 1024}
# 0.0 0.39269908169872414 {'11': 42, '00': 982}
# 0.0 0.7853981633974483 {'00': 877, '11': 147}
# 0.0 1.1780972450961724 {'11': 315, '00': 709}
# 0.0 1.5707963267948966 {'11': 489, '00': 535}
# 0.39269908169872414 0.0 {'10': 34, '00': 990}
# 0.39269908169872414 0.39269908169872414 {'10': 36, '11': 35, '00': 953}
# 0.39269908169872414 0.7853981633974483 {'01': 6, '10': 42, '11': 145, '00': 831}
# 0.39269908169872414 1.1780972450961724 {'01': 5, '10': 33, '00': 694, '11': 292}
# 0.39269908169872414 1.5707963267948966 {'01': 18, '10': 17, '00': 500, '11': 489}
# 0.7853981633974483 0.0 {'10': 127, '00': 897}
# 0.7853981633974483 0.39269908169872414 {'01': 4, '10': 133, '11': 43, '00': 844}
# 0.7853981633974483 0.7853981633974483 {'01': 17, '11': 128, '10': 137, '00': 742}
# 0.7853981633974483 1.1780972450961724 {'01': 53, '10': 98, '00': 600, '11': 273}
# 0.7853981633974483 1.5707963267948966 {'01': 71, '10': 79, '11': 441, '00': 433}
# 1.1780972450961724 0.0 {'00': 715, '10': 309}
# 1.1780972450961724 0.39269908169872414 {'01': 16, '11': 23, '10': 305, '00': 680}
# 1.1780972450961724 0.7853981633974483 {'01': 50, '11': 106, '10': 282, '00': 586}
# 1.1780972450961724 1.1780972450961724 {'11': 224, '00': 461, '10': 230, '01': 109}
# 1.1780972450961724 1.5707963267948966 {'01': 177, '10': 159, '11': 339, '00': 349}
# 1.5707963267948966 0.0 {'00': 517, '10': 507}
# 1.5707963267948966 0.39269908169872414 {'01': 20, '11': 20, '00': 467, '10': 517}
# 1.5707963267948966 0.7853981633974483 {'01': 87, '10': 431, '00': 420, '11': 86}
# 1.5707963267948966 1.1780972450961724 {'01': 146, '10': 368, '11': 149, '00': 361}
# 1.5707963267948966 1.5707963267948966 {'10': 234, '11': 241, '00': 291, '01': 258}

# %% [markdown]
# ### Variational algorithm

# %% [markdown]
# Using a parametrized circuit $U(\theta)$, we prepare a state $\lvert \psi(\theta) \rangle = U(\theta)\lvert 0 \rangle$ and measure some expectation value using a quantum computer. A pre-defined cost function $C(\theta)$ determines how good $\theta$ is for the problem.

# %% [markdown]
# ![vqa1.png](./figs/vqa1.png)

# %% [markdown]
# ### Variational quantum classifier

# %% [markdown]
# Here, the measured expectation value is interpreted as the output of the classifier (circuit). For binary classification with inputs $\vec{x}_i$ and outputs $y_i = \{0,1\}$, we build a parametrized quantum circuit that outputs:
#
# $\lvert \psi(\vec{x}_i; \vec{\theta}) \rangle = U_{W(\vec{\theta})} U_{\phi(\vec{x}_i)} \lvert 0 \rangle$
#
# where $U_{W(\vec{\theta})}$ corresponds to the variational circuit unitary transformation, and $U_{\phi(\vec{x}_i)}$ corresponds to the data encoding circuit unitary transformation. After measuring the $n$ qubits, we derive the binary output with the help of a parity function $f: \{0,1\}^n \to \{0,1\}$, which is True if the bitstring has an odd number of 1s.

# %% [markdown]
# ![vaq2.png](./figs/vqa2.png)

# %% [markdown]
# ### Implementation prototype

# %% [markdown]
# Below we will create an *ad hoc* dataset to illustrate the basic `qiskit` components: https://qiskit.org/ecosystem/machine-learning/stubs/qiskit_machine_learning.datasets.ad_hoc_data.html
#
# The details of the implementation can be found here: https://learn.qiskit.org/course/machine-learning/variational-classification

# %% [markdown]
# #### Preparing the dataset

# %%
from qiskit.utils import algorithm_globals
from qiskit_machine_learning.datasets import ad_hoc_data
import numpy as np

# %%
np.random.seed(42)

train_data, train_labels, test_data, test_labels = (
    ad_hoc_data(
        training_size=50,
        test_size=10,
        n=2,
        gap=0.3,
        one_hot=False
    )
)

# %%
train_data[0:5]
# Out:
# array([[4.33539786, 3.51858377],
#        [1.13097336, 0.25132741],
#        [2.136283  , 4.27256601],
#        [3.39292007, 3.83274304],
#        [5.2150438 , 1.0681415 ]])

# %%
train_labels[0:5]
# Out:
# array([0, 0, 0, 0, 0])

# %% [markdown]
# #### Building the training circuit

# %%
from qiskit.circuit.library import ZZFeatureMap, TwoLocal

# %%
feature_map = ZZFeatureMap(feature_dimension=2, reps=2)
variational_qc = TwoLocal(2, ['ry', 'rz'], 'cz', reps=2)

# %%
feature_map.decompose().draw('mpl')

# %%
variational_qc.decompose().draw('mpl')

# %%
qc = feature_map.compose(variational_qc)
qc.measure_all()
qc.decompose().draw('mpl')

# %% [markdown]
# ### Qiskit implementation

# %% [markdown]
# Fortunately, `qiskit` implements variational quantum classifiers in the VQC class: https://qiskit.org/ecosystem/machine-learning/stubs/qiskit_machine_learning.algorithms.VQC.html
#
# Other algorithms can be found here: https://qiskit.org/ecosystem/machine-learning/apidocs/qiskit_machine_learning.algorithms.html#

# %%
from sklearn.preprocessing import OneHotEncoder
from qiskit_machine_learning.algorithms.classifiers import VQC
from qiskit.algorithms.optimizers import SPSA

# %%
class OptimizerLog:
    """
    Store VQC optimizer's intermediate steps.
    """
    def __init__(self):
        self.evaluations = []
        self.parameters = []
        self.costs = []

    def update(self, evaluation, parameter, cost, _stepsize, _accept):
        self.evaluations.append(evaluation)
        self.parameters.append(parameter)
        self.costs.append(cost)

# %%
encoder = OneHotEncoder()

train_data, train_labels, test_data, test_labels = (
    ad_hoc_data(
        training_size=20,
        test_size=5,
        n=2,
        gap=0.3,
        one_hot=False
    )
)

train_labels_hot = encoder.fit_transform(train_labels.reshape(-1,1)).toarray()
test_labels_hot = encoder.fit_transform(test_labels.reshape(-1,1)).toarray()

# %% [markdown]
# We can then initialize the circuit's parameter, and simply fit them to the data!

# %%
# logging object
log = OptimizerLog()

# circuit definition
feature_map = ZZFeatureMap(feature_dimension=2, reps=2)
variational_qc = TwoLocal(2, ['ry', 'rz'], 'cz', reps=2)

# initialize
initial_parameters = np.array(variational_qc.num_parameters)

# build classifier
vqc = VQC(
    feature_map = feature_map,
    ansatz = variational_qc,
    loss = "cross_entropy",
    optimizer = SPSA(maxiter=100, callback = log.update),
    quantum_instance = Aer.get_backend('aer_simulator')   
)

# %%
vqc.fit(train_data, train_labels_hot)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(np.array(log.evaluations)/3, log.costs)
plt.xlabel('Step');
plt.ylabel('Cost');
